# %% [markdown]
# <a href="https://colab.research.google.com/github/vavana619/Dacon-Daily-Python-Camp/blob/main/Lv1_%EB%AA%A8%EB%8D%B8%EB%A7%81_6_6_submission_%EC%83%9D%EC%84%B1_(to_csv()).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [↩️ 리스트로 돌아가기](https://dacon.io/competitions/open/235698/overview/description)

# %% [markdown]
# # 셀을 실행할 때 팝업이 뜨면 `무시하고 계속하기` 를 눌러주세요

# %% [markdown]
# ## 데이터 다운로드
# ---
# 아래 셀을 실행시켜 데이터를 colab에 불러옵니다.
# 셀 실행은 Ctrl + Enter 를 이용해 실행 시킬 수 있습니다.

# %%
# 데이터 다운로드 링크로 데이터를 코랩에 불러옵니다.

# !wget 'https://bit.ly/3gLj0Q6'

import zipfile
with zipfile.ZipFile('3gLj0Q6', 'r') as existing_zip:
    existing_zip.extractall('data')
# Out:
# --2022-05-19 06:53:47--  https://bit.ly/3gLj0Q6
# Resolving bit.ly (bit.ly)... 67.199.248.11, 67.199.248.10
# Connecting to bit.ly (bit.ly)|67.199.248.11|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://drive.google.com/uc?export=download&id=1or_QN1ksv81DNog6Tu_kWcZ5jJWf5W9E [following]
# --2022-05-19 06:53:47--  https://drive.google.com/uc?export=download&id=1or_QN1ksv81DNog6Tu_kWcZ5jJWf5W9E
# Resolving drive.google.com (drive.google.com)... 142.251.45.14, 2607:f8b0:4004:c07::64, 2607:f8b0:4004:c07::8a, ...
# Connecting to drive.google.com (drive.google.com)|142.251.45.14|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0c-10-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/8cepb326cq5cjmudmg36daencsnqjp2j/1652943225000/17946651057176172524/*/1or_QN1ksv81DNog6Tu_kWcZ5jJWf5W9E?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2022-05-19 06:53:48--  https://doc-0c-10-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/8cepb326cq5cjmudmg36daencsnqjp2j/1652943225000/17946651057176172524/*/1or_QN1ksv81DNog6Tu_kWcZ5jJWf5W9E?e=download
# Resolving doc-0c-10-docs.googleusercontent.com (doc-0c-10-docs.googleusercontent.com)... 172.217.13.225, 2607:f8b0:4004:809::2001
# Connecting to doc-0c-10-docs.googleusercontent.com (doc-0c-10-docs.googleusercontent.com)|172.217.13.225|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39208 (38K) [application/zip]
# Saving to: ‘3gLj0Q6’
#
# 3gLj0Q6             100%[===================>]  38.29K  --.-KB/s    in 0s
#
# 2022-05-19 06:53:48 (127 MB/s) - ‘3gLj0Q6’ saved [39208/39208]

# %% [markdown]
# ## 라이브러리 불러오기
# ---
# 아래 셀을 실행시켜 pandas 와 DecisionTreeClassifier 를 불러옵니다.

# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# ## 데이터 불러오기
# ---
# 아래 셀을 실행시켜 csv 파일 데이터를 DataFrame 객체로 불러옵니다.

# %%
train = pd.read_csv('data/train.csv') 
test = pd.read_csv('data/test.csv')

# %% [markdown]
# ## 결측치 전처리
# ---
# train 의 결측치는 제거하고, test 의 결측치는 모두 0으로 대체합니다.

# %%
test = test.fillna(0)
train = train.dropna()

print(train.isnull().sum())
# Out:
# id                        0
# hour                      0
# hour_bef_temperature      0
# hour_bef_precipitation    0
# hour_bef_windspeed        0
# hour_bef_humidity         0
# hour_bef_visibility       0
# hour_bef_ozone            0
# hour_bef_pm10             0
# hour_bef_pm2.5            0
# count                     0
# dtype: int64

# %% [markdown]
# ## 모델 훈련
# ---

# %%
X_train = train.drop(['count'], axis=1)
Y_train = train['count']

# %%
model = DecisionTreeRegressor()
model.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# ## 테스트 예측
# ---
# predict() 를 이용해 test data 를 훈련된 모델로 예측한 data array 를 생성합니다.

# %%
pred = model.predict(test)

# %% [markdown]
# ## 👋 실습
# ---
# 1. submission.csv 파일을 read_csv() 를 이용해 df 클래스로 불러옵니다.
# 2. submission df 파일의 `count` 피쳐를 예측결과로 할당합니다.
# 3. submission df 파일을 to_csv() 를 이용해 csv 파일로 내보닙니다. 여기서 index 옵션은 False 로 지정해주어야 정답 형식과 맞아 떨어져 헤더 오류가 나지 않습니다.

# %%
# submission.csv 파일 df 파일로 불러오기
submission = pd.read_csv('data/submission.csv')

# %%
# submission df 파일의 count 피쳐에 예측결과 할당하기
submission['count'] = pred

# %%
# 제출파일 생성하기
submission.to_csv('sub.csv', index=False) # 인덱스 내보내지 않음

# %% [markdown]
# ## 정답 (`숨겨진 셀 n개` 를 누르세요.)
# ---
# 질문사항을 얼마든지 [게시글](https://dacon.io/competitions/open/235698/talkboard/403540?page=1&dtype=recent)에 남겨주세요 😉 <br>
# 궁금한 것, 이해가 안 되는 것, 원리, 확장개념, 참고 등등 모든 범위에서 얼마든지 질문을 달아주세요 🙋

# %%
submission = pd.read_csv('data/submission.csv')

# %%
submission['count'] = pred

# %%
submission.to_csv('sub.csv',index=False)

# %% [markdown]
# # [↩️ 리스트로 돌아가기](https://dacon.io/competitions/open/235698/overview/description)
